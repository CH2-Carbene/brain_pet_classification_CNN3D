# %%
import pandas as pd
import os
import numpy as np

# %%
a=pd.read_csv("./unusable.csv")
filename="A4_C3COMP_PRV2.csv"

# %%
df=pd.read_csv(os.path.join("./document",filename))[["BID","Sex"]]
a=df.drop_duplicates(["BID","Sex"])
b=np.array(a["BID"])
len(b)
    # print(i)
# Out:
# 5580

# %%
def f(ag:int=3):
    print(ag)
f(true)
# Out:
# <class 'bool'>

# %%
for line in a.iloc():
    print(line)
# Out:
# BID    B10018169
# Sex         Male
# Name: 0, dtype: object
# BID    B10021023
# Sex       Female
# Name: 20, dtype: object
# BID    B10081264
# Sex       Female
# Name: 40, dtype: object
# BID    B10093965
# Sex         Male
# Name: 60, dtype: object
# BID    B10102783
# Sex       Female
# Name: 80, dtype: object
# BID    B10106934
# Sex       Female
# Name: 100, dtype: object
# BID    B10108368
# Sex       Female
# Name: 120, dtype: object
# BID    B10117310
# Sex         Male
# Name: 140, dtype: object
# BID    B10139912
# Sex         Male
# Name: 160, dtype: object
# BID    B10147592
# Sex         Male
# Name: 180, dtype: object
# BID    B10149443
# Sex       Female
# Name: 200, dtype: object
# BID    B10197194
# Sex       Female
# Name: 210, dtype: object
# BID    B10249960
# Sex       Female
# Name: 220, dtype: object
# BID    B10250828
# Sex       Female
# Name: 240, dtype: object
# BID    B10256269
# Sex       Female
# Name: 250, dtype: object
# BID    B10263380
# ...
